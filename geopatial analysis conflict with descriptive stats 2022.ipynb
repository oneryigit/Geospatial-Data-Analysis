# %%
import pandas as pd
import geopandas as gpd

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style='white')
# %%
df= pd.read_stata('/Users/oneryigit/Desktop/kurd2011/kurd_r_ucpd.dta')


df5=pd.crosstab(df.ohal,df.class_lca, normalize='index')


df5=df5.applymap('{:,.2f}'.format)


df5.iloc[:,0]=pd.to_numeric(df5.iloc[:,0])
df5.iloc[:,1]=pd.to_numeric(df5.iloc[:,1])
df5.iloc[:,2]=pd.to_numeric(df5.iloc[:,2])
df5.iloc[:,3]=pd.to_numeric(df5.iloc[:,3])

df5=df5*100

# %%
#Ohal Province

# reset the plot configurations to default
#plt.rcdefaults()

plt.style.use('seaborn-white')
plt.rcParams.update({'font.size': 13}) #to set font size for all properties of plot
plt.rcParams.update({'font.sans-serif':'Times New Roman'}) #or 'helvetica'

fig, ax = plt.subplots(figsize=(8,6))

my_palette = ["#E5E4E4", "#BFBFBF",'#6D6D6D', "#030303"]

cmap=sns.set_palette(palette=my_palette)

plot=df5.plot(ax=ax, kind='bar', stacked=False, cmap=cmap, width=0.5)


for p in plot.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height}''%', (x + width/2, y + height*1.005), ha='center', size=12)


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

#ax.set_title('Support for Minority Rights by OHAL Province',pad=25, fontdict={'fontsize':16})
ax.set_xlabel('Emergency Rule Province',fontdict={'fontsize':14})
ax.set_ylabel('Percentage of Participants',fontdict={'fontsize':15})
plt.legend(['No Support','Socio-Cultural', 'Decentralization','All Political Support'], 
           title= 'Support Minority Rights',fontsize='small',fancybox=False, title_fontsize='medium',
          frameon=False, loc=[0.1, 0.8])
ax.set_xticklabels(['Not OHAL Province', 'OHAL Province'], fontdict={'fontsize':14}, rotation=0);
plt.tick_params(left=False,labelleft = False)
ax.grid(False)
ax.set_xlabel('')
# #plt.axis('off')
fig.tight_layout()
ax.set_facecolor("w")
fig.set_facecolor('w')
plt.show()

fig.savefig('group_rights_demands_by_province.png',bbox_inches='tight');
fig.savefig('group_rights_demands_by_province.pdf',bbox_inches='tight');

# %%
## Souteastern Provinces
df5=pd.crosstab(df.se_region,df.class_lca, normalize='index')


df5=df5.applymap('{:,.2f}'.format)

df5.iloc[:,0]=pd.to_numeric(df5.iloc[:,0])
df5.iloc[:,1]=pd.to_numeric(df5.iloc[:,1])
df5.iloc[:,2]=pd.to_numeric(df5.iloc[:,2])
df5.iloc[:,3]=pd.to_numeric(df5.iloc[:,3])

df5=df5*100

# %%

# reset the plot configurations to default
#plt.rcdefaults()

plt.style.use('seaborn-white')
plt.rcParams.update({'font.size': 13}) #to set font size for all properties of plot
plt.rcParams.update({'font.sans-serif':'Times New Roman'}) #or 'helvetica'

fig, ax = plt.subplots(figsize=(8,6))

my_palette = ["#E5E4E4", "#BFBFBF",'#6D6D6D', "#030303"]

cmap=sns.set_palette(palette=my_palette)

plot=df5.plot(ax=ax, kind='bar', stacked=False, cmap=cmap, width=0.5)


for p in plot.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height}''%', (x + width/2, y + height*1.005), ha='center', size=12)


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

#ax.set_title('Support for Minority Rights by Southeastern Province',pad=30, fontdict={'fontsize':16})
ax.set_xlabel('Southeastern Province',fontdict={'fontsize':14})
ax.set_ylabel('Percentage of Participants',fontdict={'fontsize':15})
plt.legend(['No Support','Socio-Cultural', 'Decentralization','All Political Support'], 
           title= 'Support Minority Rights',fontsize='small',fancybox=False, title_fontsize='medium',
          frameon=False, loc=[0.1, 0.8])
ax.set_xticklabels(['Not Southeastern Province', 'Southeastern Province'], fontdict={'fontsize':14}, rotation=0);
plt.tick_params(left=False,labelleft = False)
ax.grid(False)
ax.set_xlabel('')
# #plt.axis('off')
#fig.tight_layout()
ax.set_facecolor("w")
fig.set_facecolor('w')
plt.show()

fig.savefig('group_rights_demands_by_Southeastern_province.png',bbox_inches='tight');
fig.savefig('group_rights_demands_by_Southeastern_province.pdf',bbox_inches='tight');

# %%
## Migration

df5=pd.crosstab(df.zor_gocguv2,df.class_lca, normalize='index')


df5=df5.applymap('{:,.2f}'.format)

df5.iloc[:,0]=pd.to_numeric(df5.iloc[:,0])
df5.iloc[:,1]=pd.to_numeric(df5.iloc[:,1])
df5.iloc[:,2]=pd.to_numeric(df5.iloc[:,2])
df5.iloc[:,3]=pd.to_numeric(df5.iloc[:,3])

df5=df5*100


df5.iloc[1,0]=14.0
df5.iloc[1,3]=55.0

#df5.iloc[1,3]=14.0
# reset the plot configurations to default
#plt.rcdefaults()

plt.style.use('seaborn-white')
plt.rcParams.update({'font.size': 13}) #to set font size for all properties of plot
plt.rcParams.update({'font.sans-serif':'Times New Roman'}) #or 'helvetica'

fig, ax = plt.subplots(figsize=(8,6))

my_palette = ["#E5E4E4", "#BFBFBF",'#6D6D6D', "#030303"]

cmap=sns.set_palette(palette=my_palette)

plot=df5.plot(ax=ax, kind='bar', stacked=False, cmap=cmap, width=0.6)


for p in plot.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height}''%', (x + width/2, y + height*1.005), ha='center', size=12)


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

#ax.set_title('Support for Minority Rights by Forced Displacement',pad=30, fontdict={'fontsize':16})
ax.set_xlabel('Forced Displacement',fontdict={'fontsize':14})
ax.set_ylabel('Percentage of Participants',fontdict={'fontsize':14})
plt.legend(['No Support','Socio-Cultural', 'Decentralization','All Political Support'], 
           title= 'Support Minority Rights',fontsize='small',fancybox=False, title_fontsize='medium',
          frameon=False, loc=[0.1, 0.7])
ax.set_xticklabels(['No Forced Displacement', 'Forced Displacement'], fontdict={'fontsize':14}, rotation=0);
plt.tick_params(left=False,labelleft = False)
ax.grid(False)
ax.set_xlabel('')
# #plt.axis('off')
#fig.tight_layout()
ax.set_facecolor("w")
fig.set_facecolor('w')

plt.show()
fig.savefig('group_rights_demands_by_mig.png',bbox_inches='tight');
fig.savefig('group_rights_demands_by_mig.pdf',bbox_inches='tight');

# %%
df5=pd.crosstab([df.zor_gocguv2,df.ohal, df.se_region],df.class_lca)
df5



# reset the plot configurations to default
#plt.rcdefaults()

plt.style.use('seaborn-white')
plt.rcParams.update({'font.size': 18}) #to set font size for all properties of plot
plt.rcParams.update({'font.sans-serif':'Times New Roman'}) #or 'helvetica'

fig, ax = plt.subplots(figsize=(10,8))

my_palette = ["#E5E4E4", "#BFBFBF",'#6D6D6D', "#030303"]

cmap=sns.set_palette(palette=my_palette)

plot=df5.plot(ax=ax, kind='bar', stacked=False, cmap=cmap, width=.95)


for p in plot.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height}', (x + width/2, y + height*1.005), ha='center')


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

ax.set_title('Support for Group Rights (Count)',pad=30, fontdict={'fontsize':20})
ax.set_xlabel('Forced Migration, OHAL, Southeastern Province',fontdict={'fontsize':20})
ax.set_ylabel('Number of Participants',fontdict={'fontsize':20})
plt.legend(['No Demand','Socio-Cultural', 'Decentralization','Full Scale Demand'], 
           title= 'Group Class  ',fontsize='small',fancybox=False, title_fontsize='small',
          frameon=False, loc="best")
ax.set_xticklabels(['NNN', 'NNY','NYN','NYY','YNN','YNY','YYN','YYY'], fontdict={'fontsize':20}, rotation=0);
plt.tick_params(left=False,labelleft = False)
ax.grid(False)
# #plt.axis('off')
#fig.tight_layout()
ax.set_facecolor("w")
fig.set_facecolor('w')
fig.savefig('group_rights_demands_by_all.png',bbox_inches='tight', dpi=300);
fig.savefig('group_rights_demands_by_all.pdf',bbox_inches='tight', dpi=300);

# %%
import numpy as np
# By individual Provinces

df= pd.read_stata('/Users/oneryigit/Desktop/kurd2011/kurd_r_ucpd.dta')

df2 = df.replace(r'^\s*$', np.nan, regex=True)

df2 = df2[df2['adm_1'].notnull()]

df3=df2[['adm_1', 'class_lca']]

df4=df3.sort_values(by=['adm_1', 'class_lca'])


cross_tab=pd.crosstab(df4.adm_1, df4.class_lca)

cross_tab=cross_tab.rename(columns={1.0:'No Demand', 2.0:'Socio-Cultural Demand', 3.0:'Decentralization', 4.0:'Full Scale Demand'})


cross_tab=cross_tab.reset_index()


cross_tab= cross_tab.sort_values(by=['Full Scale Demand', 'Decentralization', 'Socio-Cultural Demand', 'No Demand',],ascending=False)


cross_tab.loc[9,'adm_1']='Diyarbakır'
cross_tab.loc[7,'adm_1']='Bingöl'
cross_tab.loc[31,'adm_1']='Şanlıurfa'
cross_tab.loc[5,'adm_1']='Ağrı'
cross_tab.loc[22,'adm_1']='Muş'
cross_tab.loc[1,'adm_1']='Adıyaman'
cross_tab.loc[32,'adm_1']='Şırnak'
cross_tab.loc[10,'adm_1']='Elazığ'
cross_tab.loc[2,'adm_1']='Ankara'
cross_tab.loc[16,'adm_1']='Iğdır'
cross_tab.loc[29,'adm_1']='İstanbul'
cross_tab.loc[17,'adm_1']='Kahramanmaraş'
cross_tab.loc[4,'adm_1']='Aydın'
cross_tab.loc[30,'adm_1']='İzmir'

cross_tab

# %%



# reset the plot configurations to default
#plt.rcdefaults()

plt.style.use('seaborn-white')
plt.rcParams.update({'font.size': 18}) #to set font size for all properties of plot
plt.rcParams.update({'font.sans-serif':'Times New Roman'}) #or 'helvetica'

fig, ax = plt.subplots(figsize=(14,4))

my_palette = ["#E5E4E4", "#BFBFBF",'#6D6D6D', "#030303"]

cmap=sns.set_palette(palette=my_palette)

cross_tab.plot(ax=ax, kind='bar', stacked=True, cmap=cmap)

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

#ax.set_title('Support for Minority Rights by City', pad=35,fontdict={'fontsize':20})
#ax.set_xlabel('City',fontdict={'fontsize':20})
ax.set_ylabel('Number of Participants',fontdict={'fontsize':20})
plt.legend(['No Support','Socio-Cultural', 'Decentralization','All Political Support'], frameon=False,title= 'Support Minority Rights',fontsize='small',fancybox=True, title_fontsize=r'small')
ax.set_xticklabels(cross_tab.adm_1, size=16);
ax.axis()
ax.grid(False)

#plt.axis('off')
fig.tight_layout()
ax.set_facecolor("w")
fig.set_facecolor('w')
fig.savefig('group_rights_demands_by_province_2011.png',bbox_inches='tight');
fig.savefig('group_rights_demands_by_province_2011.pdf',bbox_inches='tight');
plt.show()

# %%
# Mapping Kurdish Conflict

ucpd= pd.read_csv('ged211.csv')
ucpd = ucpd[ucpd['side_a'] == 'Government of Turkey']
ucpd_2010=ucpd[ucpd.year<2011]
ucpd_2010_pkk = ucpd_2010[ucpd_2010['side_b'].apply(lambda val: all(val != s for s in ['MKP', 'DHKP-C']))]

tr_geo=gpd.read_file('turkey shape/tur_polbnda_adm1.shp')

#Transforming UCPD Dataset as geo-data frame

gs = gpd.GeoSeries.from_wkt(ucpd_2010_pkk['geom_wkt'])
geo_event = gpd.GeoDataFrame(ucpd_2010_pkk, geometry=gs, crs="EPSG:4326")

#For some reasons where were some event points that did not match with the map.
#Upon checing they did not have proper province location. So I droped them.
#Nevsehir and Konya

geo_event=geo_event.drop(index=252568, axis=0)

geo_event[(geo_event.longitude>33)&(geo_event.longitude<35.9) & 
          (geo_event.latitude>38)&(geo_event.latitude<40)].index

geo_event=geo_event.drop(index=geo_event[(geo_event.longitude>33)&(geo_event.longitude<35.9) & 
          (geo_event.latitude>38)&(geo_event.latitude<40)].index)


#This will be the first layer of our map. 
world = gpd.read_file('IPUMSI_world_release2020/world_countries_2020.shp')


#Okay here, to plot names of countries, I enter coordinates of capitals
#Some capitals were far away, in that case, I use another close city point (e.g. iran)
cities={'city':['Turkey', 'Syria', 'Iran', 'Iraq','Armenia'],
    'longitude':[32.5597, 37.2765, 45.6786,44.3661, 44.5152],
    'latitude':[39.9334, 34.6138, 37.54982,34.3152,40.1872]}

cities_df=pd.DataFrame(cities)



#turn cities_df into a geo dataframe from xy coordinates. 
city_geo = gpd.GeoDataFrame(cities_df, 
                            geometry=gpd.points_from_xy(cities_df.longitude,cities_df.latitude),
                            crs="EPSG:4326")



#this is an important step. I aggragate number of conflict in each city with intensity level
agg_ucpd=geo_event.groupby(by='adm_1').agg({'deaths_a':'sum','deaths_b':'sum', 'deaths_civilians':'sum', 'id':'count'})

agg_ucpd.reset_index(inplace=True)

agg_ucpd.adm_1=agg_ucpd.adm_1.str.replace(' province','')


#Load the saved data. 
agg_ucpd= pd.read_stata('agg_ucdp.dta')


#I created a variable called 'ohal'=0
#then I manually enter the ohal cities=1
agg_ucpd.loc[1,'ohal']=1
agg_ucpd.loc[36,'ohal']=1
agg_ucpd.loc[7,'ohal']=1
agg_ucpd.loc[8,'ohal']=1
agg_ucpd.loc[10,'ohal']=1
agg_ucpd.loc[11,'ohal']=1
agg_ucpd.loc[17,'ohal']=1
agg_ucpd.loc[25,'ohal']=1
agg_ucpd.loc[27,'ohal']=1
agg_ucpd.loc[32,'ohal']=1
agg_ucpd.loc[34,'ohal']=1
agg_ucpd.loc[37,'ohal']=1
agg_ucpd.loc[29,'ohal']=1

#so basically i try to come up with a column to merge.
#i found adm1 variable is actually plaka no but has some extra words. Delete them first.

tr_geo.adm1=tr_geo.adm1.str.replace('TUR0','')


#make sure the type is int, otherwise error. 
tr_geo.adm1=tr_geo.adm1.astype('int')

tr_geo_ucpd_agg=pd.merge(tr_geo, agg_ucpd, how='left', left_on='adm1', right_on='soru34')
tr_geo_ucpd_agg['total_deaths']=tr_geo_ucpd_agg.deaths_a + tr_geo_ucpd_agg.deaths_b + tr_geo_ucpd_agg.deaths_civilians

ohal_cities=tr_geo_ucpd_agg[tr_geo_ucpd_agg.loc[:,'ohal']==1]
# Out:
# /var/folders/lb/87v_57_5429939_f527p9dvr0000gn/T/ipykernel_72559/2948178506.py:3: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   ucpd= pd.read_csv('ged211.csv')

# %%
# reset the plot configurations to default
#plt.rcdefaults()

plt.style.use('seaborn-white')
plt.rcParams.update({'font.size': 18}) #to set font size for all properties of plot
plt.rcParams.update({'font.sans-serif':'Times New Roman'}) #or 'helvetica'


fig, ax= plt.subplots(figsize=(15, 10))

#cmap=sns.cubehelix_palette(start=3.3, rot=0, dark=0, light=.95, reverse=False, as_cmap=True)


world.plot(ax=ax, alpha=0.2, color='gray', edgecolor='k')
tr_geo.plot(ax=ax, alpha=0.3, color='gray', edgecolor='k')
tr_geo_ucpd_agg.plot(column='total_deaths', cmap='viridis', ax=ax, edgecolor='gray',legend=True,legend_kwds={'shrink': 0.5, 'label':'Number of deaths'})
#ohal_cities.plot(column='ohal', cmap='Greens', ax=ax, alpha=0.2, edgecolor='green', lw=3.5)
geo_event.plot(ax=ax, c='r', alpha=1, edgecolor='red',markersize=14)

city_geo.plot(ax=ax)
for x, y, label in zip(city_geo.geometry.x, city_geo.geometry.y, city_geo.city):
    ax.annotate(label,size=18, xy=(x, y), xytext=(-15, 10), textcoords="offset points")

ax.axis([25,49, 33,44])  
#ax.set_title('Ethnic Conflict in Turkey (1989 - 2010)',pad=20, fontdict={'fontsize':20})
ax.grid(False)


from matplotlib.patches import Patch
from matplotlib.lines import Line2D

legend_elements = [Line2D([0], [0], marker='o', color='w', label='Conflict Events',
                          markerfacecolor='r', markersize=8, alpha=1),
                  Patch(facecolor='Gray', edgecolor='k',
                         label='No Kurdish Data', alpha=0.3)]
ax.legend(handles=legend_elements, loc='lower left', fontsize=15,shadow=False, frameon=False)


plt.axis('off')
fig.tight_layout()
fig.set_facecolor("w")
plt.show()

fig.savefig('Map_Turkey.pdf',bbox_inches='tight')
fig.savefig('Map_Turkey.png',bbox_inches='tight')
